# %% [markdown]
# ## Homework 1
#
# 1) How would you define Machine Learning?
# 2) What are the differences between Supervised and Unsupervised Learning? Specify example 3 algorithms   for each of these.
# 3) What are the test and validation set, and why would you want to use them?
# 4) What are the main preprocessing steps? Explain them in detail. Why we need to prepare our data?
# 5) How you can explore and analyse countionus and discrete variables?
# 6) Analyse the plot given below. (What is the plot and variable type, check the distribution and make comment about how you can preproccess it.)

# %% [markdown]
# 1. Makine öğrenmesi büyük miktarlarda veri içerisinde yer alan ve insan olarak öğrenmemizin mümkün olmadığı yapıları öğrenme işine yarar.
#
# 2.Denetimli: Tüm veriler etiketlidir ve algoritmalar giriş verilerinden çıktıyı tahmin etmeyi öğrenir. (lineer regresyon, lojistik regresyon ve RIDGE/LASSO/ELASTICNET regresyon vb)Denetimsiz: Veriler etiketsizdir ve algoritmalar, giriş verilerinden doğal yapıyı öğrenir.(K-MEANS, Hiyerarşik Kümeleme, Mini Batch K-MEANS vb)
#
# 3. Ana veriden %70 oranında alınan training data içinden seçtiğimiz ve algoritmamızdaki hiperparametreleri ayarlayarak modeli fit ettiğimiz settir. Ana verinin %30 oranında ayrılan ve modeli değerlendirdiğimiz set ise test settir.
#
# 4. Tekrar eden, boş veya hatalı olan verileri temizlenir. Ardından standart sapma değerini büyüten outlier tespit edilir. Daha sonra feature scaling ve bucketing işlemleri ile veri işlenmeye hazır hale getirilir.
#
# 5. Discrete variables sayılarak elde edilir. Countionus variables ölçülerek elde edilir.
#
# 6. Countionus variables, petal width feature kullanılarak ayrıştırılmıştır.
